# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

#from itertools import islice

# %%
data = pd.read_excel('../data/telecom_data.xlsx')

# %%
data_UserEngagement = pd.DataFrame()
data_UserEngagement['msisdn'] = data['MSISDN/Number']
data_UserEngagement['BId'] = data['Bearer Id']
data_UserEngagement['Dur'] = data['Dur. (ms)']
data_UserEngagement['total'] = data['Total DL (Bytes)'] + data['Total UL (Bytes)']

UserEngagement = data_UserEngagement.groupby('msisdn').aggregate({'BId': 'count','Dur': 'sum','total': 'sum',}).rename(columns={"BId": "sessions_freq", "Dur": "sessions_dur(.ms)", "total": "sessions_traff"})

# %%
UserEngagement
# Out:
#               sessions_freq  sessions_dur(.ms)  sessions_traff
# msisdn
# 3.360100e+10              1           116720.0    8.786906e+08
# 3.360100e+10              1           181230.0    1.568596e+08
# 3.360100e+10              1           134969.0    5.959665e+08
# 3.360101e+10              1            49878.0    4.223207e+08
# 3.360101e+10              2            37104.0    1.457411e+09
# ...                     ...                ...             ...
# 3.379000e+10              1             8810.0    7.146416e+08
# 3.379000e+10              1           140988.0    4.803073e+08
# 3.197021e+12              1           877385.0    2.321240e+08
# 3.370000e+14              1           253030.0    5.962878e+08
# 8.823971e+14              1           869844.0    1.391536e+08
#
# [106856 rows x 3 columns]

# %% [markdown]
# # Top 10 users based on session frequency

# %%
topUsers_SF = UserEngagement.sort_values(by = 'sessions_freq', ascending = False).head(10)
topUsers_SF['sessions_freq']
# Out:
# msisdn
# 3.362632e+10    18
# 3.362578e+10    17
# 3.361489e+10    17
# 3.365973e+10    16
# 3.376054e+10    15
# 3.367588e+10    15
# 3.366716e+10    13
# 3.362708e+10    12
# 3.360452e+10    12
# 3.376041e+10    12
# Name: sessions_freq, dtype: int64

# %% [markdown]
# # Top 10 users based on the total duration(ms) of all the sessions

# %%
topUsers_TD = UserEngagement.sort_values(by = 'sessions_dur(.ms)', ascending = False).head(10)
topUsers_TD['sessions_dur(.ms)']
# Out:
# msisdn
# 3.362578e+10    18553754.0
# 3.361489e+10     9966898.0
# 3.376054e+10     9279434.0
# 3.362632e+10     8791927.0
# 3.366716e+10     8744914.0
# 3.366284e+10     6614270.0
# 3.366469e+10     6288730.0
# 3.360313e+10     6287761.0
# 3.366746e+10     5649882.0
# 3.376041e+10     5321667.0
# Name: sessions_dur(.ms), dtype: float64

# %% [markdown]
# # Top 10 users based on the total traffic(bytes) of all the sessions

# %%
topUsers_TS = UserEngagement.sort_values(by = 'sessions_traff', ascending = False).head(10)
topUsers_TS['sessions_traff']
# Out:
# msisdn
# 3.361489e+10    8.846226e+09
# 3.376054e+10    8.514774e+09
# 3.362578e+10    8.499621e+09
# 3.362632e+10    7.971167e+09
# 3.367588e+10    7.891111e+09
# 3.365973e+10    7.705863e+09
# 3.366646e+10    7.308501e+09
# 3.376041e+10    7.132371e+09
# 3.366471e+10    6.872018e+09
# 3.369879e+10    6.540899e+09
# Name: sessions_traff, dtype: float64

# %%
normalized_UserEngagement_data= np.log1p(UserEngagement)
normalized_UserEngagement_data.head()
# Out:
#               sessions_freq  sessions_dur(.ms)  sessions_traff
# msisdn
# 3.360100e+10       0.693147          11.667542       20.593943
# 3.360100e+10       0.693147          12.107528       18.870862
# 3.360100e+10       0.693147          11.812808       20.205695
# 3.360101e+10       0.693147          10.817355       19.861276
# 3.360101e+10       1.098612          10.521507       21.099927

# %%
Kmean_clustering = KMeans(n_clusters = 3, init = 'k-means++', random_state =0, max_iter = 1000)
Kmean_clustering.fit(normalized_UserEngagement_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\metrics\pairwise.py:54: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   dtype = np.float
# ...
